# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# **KONARK TYAGI**
# Currently i am working as sales manager in health sector and want to upgrade myself as a data scientist.

# %% [markdown]
# *i want to be a data scientist because of the great scope of data science in coming years. As a sales manager i see that a company can grow with its data as data scientist can tell the needs of the customer and can give the best product from the company to the customers.*

# %% [markdown]
# ###in the next cell the code will be of subtraction

# %%
a = 10
b = 5
print(a,b)
# Out:
# 10 5

# %%
a-b
# Out:
# 5

# %% [markdown]
# - this is a bullet
#     - this is a sub bullet
# 1. this is number one line
# 2. this is number two line
#     A. this is sub line one
#     B. this is sub line two
# ![data%20science.jpg](attachment:data%20science.jpg)
